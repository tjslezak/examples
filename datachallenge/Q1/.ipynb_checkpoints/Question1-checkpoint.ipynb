# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.sandbox.regression.predstd import wls_prediction_std
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LinearRegression


print('Question 1')
print('Q1: The Civilian Complaint Review Board (CCRB) of New York City releases anonymized data about complaints it has received reguarding civilian interactions with police. Besides their aggregated reporting data, they release record-level data as an Excel spreadsheet. Download this data. A description of the data appears in the first sheet of the spreadsheet, which could be useful to your analysis.')
# Out:
# /Users/tjs/anaconda3/envs/bikemap/lib/python3.7/site-packages/sklearn/utils/__init__.py:4: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Sequence
# /Users/tjs/anaconda3/envs/bikemap/lib/python3.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# Question 1
# Q1: The Civilian Complaint Review Board (CCRB) of New York City releases anonymized data about complaints it has received reguarding civilian interactions with police. Besides their aggregated reporting data, they release record-level data as an Excel spreadsheet. Download this data. A description of the data appears in the first sheet of the spreadsheet, which could be useful to your analysis.

# %%
print("1. How many unique complaints (identified by 'UniqueComplaintId') with complete information (i.e. there are no missing values) appear in the dataset?")
# Out:
# 1. How many unique complaints (identified by 'UniqueComplaintId') with complete information (i.e. there are no missing values) appear in the dataset?

# %%
data = pd.read_excel('ccrb_datatransparencyinitiative_20170207.xlsx', sheet_name='Complaints_Allegations')

# %%
df = pd.DataFrame(data, columns=data.columns)
df.dropna(inplace=True)
ndf = df.drop_duplicates('UniqueComplaintId')
len(ndf['UniqueComplaintId'].unique().tolist())
# Out:
# 68467

# %%
print('2. What proportion of complaints occur in the borough with the largest number of complaints? For this question, only consider unique complaints with complete information. ')
# Out:
# 2. What proportion of complaints occur in the borough with the largest number of complaints? For this question, only consider unique complaints with complete information.

# %%
sns.countplot(ndf['Borough of Occurrence'])
plt.title('Borough of Occurrence')
# Out:
# Text(0.5,1,'Borough of Occurrence')

# %%
bindex = ndf['Borough of Occurrence'].value_counts().index.tolist()
bvalues = ndf['Borough of Occurrence'].value_counts().values.tolist()
[x+': '+ str(y) for x,y in zip(bindex,bvalues)]
# Out:
# ['Brooklyn: 23369',
#  'Manhattan: 16067',
#  'Bronx: 15603',
#  'Queens: 10608',
#  'Staten Island: 2763',
#  'Outside NYC: 57']

# %%
ans2 = max(bvalues) / sum(bvalues)

# %%
print("Answer = " + str(ans2))
# Out:
# Answer = 0.3413177151036266

# %%
print('3. How many complaints per 100k residents were there in the borough with the highest number of complaints per capita resulting from incidents in 2016? Find the 2016 population estimates of each borough on Wikipedia. Ignore complaints from "Outside NYC". For this question, only consider unique complaints with complete information. ')
# Out:
# 3. How many complaints per 100k residents were there in the borough with the highest number of complaints per capita resulting from incidents in 2016? Find the 2016 population estimates of each borough on Wikipedia. Ignore complaints from "Outside NYC". For this question, only consider unique complaints with complete information.

# %%
df = ndf.copy()
#trend.set_index('Incident Year', inplace=True)
df = df[df['Incident Year'].isin([int(2016)])]
local = bindex[0:5]
df = df[df['Borough of Occurrence'].isin(local)]

# %%
sns.countplot(df['Borough of Occurrence'])
#complainers = df[df['Borough of Occurrence'].isin(['Brooklyn'])]

# %%
a = df['Borough of Occurrence'].value_counts().index.tolist()
b = df['Borough of Occurrence'].value_counts().values.tolist()
local_2016 = {a: b for a,b in zip(a,b)}
local_2016
# Out:
# {'Brooklyn': 1068,
#  'Manhattan': 844,
#  'Bronx': 772,
#  'Queens': 589,
#  'Staten Island': 149}

# %%
pop_2016 = {'Brooklyn': 2629150, 'Manhattan': 1643734, 
            'Bronx': 1455720, 'Queens': 2333054, 'Staten Island': 476015}

percapita = {k: local_2016[k]/pop_2016[k] for k in local_2016}
val = max(percapita, key=percapita.get)
print(val)
# Out:
# Bronx

# %%
per100k = percapita['Bronx'] * 100000
print(str(per100k) + ' complaints per 100k residents')
# Out:
# 53.032176517462155 complaints per 100k residents

# %%
print('Q4.')
# Out:
# Q4.

# %%
cdt = ndf.copy()
cdt.head()
# Out:
#     DateStamp  UniqueComplaintId  Close Year  Received Year  \
# 0  2017-02-07                  6        2006           2006
# 1  2017-02-07                 11        2006           2006
# 2  2017-02-07                 20        2006           2005
# 7  2017-02-07                 26        2006           2006
# 11 2017-02-07                 38        2006           2005
#
#    Borough of Occurrence  Is Full Investigation  Complaint Has Video Evidence  \
# 0               Brooklyn                  False                         False
# 1                  Bronx                  False                         False
# 2                  Bronx                  False                         False
# 7               Brooklyn                  False                         False
# 11                 Bronx                   True                         False
#
#       Complaint Filed Mode Complaint Filed Place  \
# 0                    Phone                   IAB
# 1                    Phone                   IAB
# 2   Call Processing System                  CCRB
# 7                    Phone                   IAB
# 11                   Phone                  CCRB
#
#     Complaint Contains Stop & Frisk Allegations Incident Location  \
# 0                                         False    Street/highway
# 1                                         False    Street/highway
# 2                                          True    Street/highway
# 7                                         False   Apartment/house
# 11                                        False   Apartment/house
#
#     Incident Year     Encounter Outcome  \
# 0            2006  No Arrest or Summons
# 1            2006                Arrest
# 2            2005  No Arrest or Summons
# 7            2006  No Arrest or Summons
# 11           2005  No Arrest or Summons
#
#                       Reason For Initial Contact Allegation FADO Type  \
# 0   PD suspected C/V of violation/crime - street          Discourtesy
# 1                                          Other                Force
# 2                                          Other   Abuse of Authority
# 7                                 Report-dispute   Abuse of Authority
# 11                       Report-domestic dispute   Abuse of Authority
#
#    Allegation Description
# 0                  Action
# 1          Physical force
# 2          Strip-searched
# 7        Threat of arrest
# 11       Property damaged

# %%
cdt['Availability'] = cdt['Close Year'] - cdt['Received Year']

# %%
avg_duration = cdt['Availability'].mean()
print(str(avg_duration) + ' years' )
# Out:
# 0.4743745161902814 years

# %%
print('Q5. Linear Regression')
fsk = ndf.copy()
fsk = fsk[fsk['Complaint Contains Stop & Frisk Allegations'].isin([True])]
time = np.arange(2007,2017)
fsk = fsk[fsk['Incident Year'].isin(time)]
sns.catplot(x="Incident Year", kind="count", palette="ch:.1", height=1.5, aspect=4, data=fsk)
# Out:
# Q5. Linear Regression

# %%
a = fsk['Incident Year'].value_counts().index.tolist()
b = fsk['Incident Year'].value_counts().values.tolist()
f = {str(a): b for a,b in zip(a,b)}
q = pd.DataFrame.from_dict(f, orient='index', columns=['count'])
f.items()
# Out:
# dict_items([('2007', 2513), ('2008', 2192), ('2009', 2187), ('2010', 1805), ('2011', 1638), ('2012', 1455), ('2013', 1237), ('2014', 975), ('2015', 877), ('2016', 685)])

# %%
wing = ndf.copy()

# %%
type(q.index)
df = q.reset_index()
type(df['index'])
df = df.rename(index=str, columns={"index": "date", "count": "num_incidents"})
df.index = pd.DatetimeIndex(df.date)
idx = pd.date_range(df.index.min(), df.index.max())

# %%
df = df.reindex(index = idx)
df.dropna(inplace=True)
tempdf = df.copy()
df
# Out:
#             date  num_incidents
# 2007-01-01  2007         2513.0
# 2008-01-01  2008         2192.0
# 2009-01-01  2009         2187.0
# 2010-01-01  2010         1805.0
# 2011-01-01  2011         1638.0
# 2012-01-01  2012         1455.0
# 2013-01-01  2013         1237.0
# 2014-01-01  2014          975.0
# 2015-01-01  2015          877.0
# 2016-01-01  2016          685.0

# %%
df.insert(df.shape[1],
          'row_count',
          df.index.value_counts().sort_index().cumsum())

# %%
pd.to_datetime(df['date']).astype(int).astype(float)
results = ols('row_count ~ num_incidents', data=df).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              row_count   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                     792.8
# Date:                Sun, 22 Jul 2018   Prob (F-statistic):           2.73e-09
# Time:                        20:52:31   Log-Likelihood:                -1.7095
# No. Observations:                  10   AIC:                             7.419
# Df Residuals:                       8   BIC:                             8.024
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        13.0658      0.287     45.489      0.000      12.403      13.728
# num_incidents    -0.0049      0.000    -28.157      0.000      -0.005      -0.004
# ==============================================================================
# Omnibus:                        0.368   Durbin-Watson:                   2.918
# Prob(Omnibus):                  0.832   Jarque-Bera (JB):                0.398
# Skew:                           0.340   Prob(JB):                        0.820
# Kurtosis:                       2.298   Cond. No.                     4.71e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.71e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/tjs/anaconda3/envs/bikemap/lib/python3.7/site-packages/scipy/stats/stats.py:1394: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   "anyway, n=%i" % int(n))

# %%
res = sm.OLS(df.num_incidents, df.row_count).fit()
print('Predicted values: ', res.predict())
# Out:
# Predicted values:  [ 178.7012987   357.4025974   536.1038961   714.80519481  893.50649351
#  1072.20779221 1250.90909091 1429.61038961 1608.31168831 1787.01298701]

# %%
fig = sns.regplot(data = df, x = 'row_count', y = 'num_incidents')
plt.show()
df
# Out:
#             date  num_incidents  row_count
# 2007-01-01  2007         2513.0          1
# 2008-01-01  2008         2192.0          2
# 2009-01-01  2009         2187.0          3
# 2010-01-01  2010         1805.0          4
# 2011-01-01  2011         1638.0          5
# 2012-01-01  2012         1455.0          6
# 2013-01-01  2013         1237.0          7
# 2014-01-01  2014          975.0          8
# 2015-01-01  2015          877.0          9
# 2016-01-01  2016          685.0         10

# %%
fig = sns.lmplot(data = df, x = 'row_count', y = 'num_incidents')

# %%
dta = tempdf.copy()
dta.index
dates = sm.tsa.datetools.dates_from_range('2007', length=len(dta.date))

# %%
dta.index = pd.Index(sm.tsa.datetools.dates_from_range('2007', '2016'))
del dta["date"]

# %%
dta
dta.plot(figsize=(12,4))

# %%
df
# Out:
#             date  num_incidents  row_count
# 2007-01-01  2007         2513.0          1
# 2008-01-01  2008         2192.0          2
# 2009-01-01  2009         2187.0          3
# 2010-01-01  2010         1805.0          4
# 2011-01-01  2011         1638.0          5
# 2012-01-01  2012         1455.0          6
# 2013-01-01  2013         1237.0          7
# 2014-01-01  2014          975.0          8
# 2015-01-01  2015          877.0          9
# 2016-01-01  2016          685.0         10

# %%
endog = pd.Series(dta.num_incidents, index=dates)
endog
# Out:
# 2007-12-31    2513.0
# 2008-12-31    2192.0
# 2009-12-31    2187.0
# 2010-12-31    1805.0
# 2011-12-31    1638.0
# 2012-12-31    1455.0
# 2013-12-31    1237.0
# 2014-12-31     975.0
# 2015-12-31     877.0
# 2016-12-31     685.0
# Name: num_incidents, dtype: float64

# %%
ar_model = sm.tsa.AR(endog, freq='A')

# %%
pandas_ar_res = ar_model.fit(maxlag=8, method='mle', disp=-1)
# Out:
# /Users/tjs/anaconda3/envs/bikemap/lib/python3.7/site-packages/statsmodels/base/model.py:488: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /Users/tjs/anaconda3/envs/bikemap/lib/python3.7/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
pred = pandas_ar_res.predict(start='2007', end='2018')
print(pred.round())
# Out:
# 2007-12-31    1765.0
# 2008-12-31    2504.0
# 2009-12-31    1948.0
# 2010-12-31    1941.0
# 2011-12-31    1676.0
# 2012-12-31    1441.0
# 2013-12-31    1254.0
# 2014-12-31     966.0
# 2015-12-31     878.0
# 2016-12-31     685.0
# 2017-12-31     508.0
# 2018-12-31     387.0
# Freq: A-DEC, dtype: float64

# %% [markdown]
# Answer = 387

# %%
print('Q6. Calculate the chi-square test statistic for testing whether a complaint is more likely to receive a full investigation when it has video evidence. For this question, only consider unique complaints with complete information.')
# Out:
# Q6. Calculate the chi-square test statistic for testing whether a complaint is more likely to receive a full investigation when it has video evidence. For this question, only consider unique complaints with complete information.

# %%
full = wing.copy()

# %%
#full = wing[wing['Is Full Investigation'].isin([True])]
full.loc[full['Complaint Has Video Evidence']==False, 'Video_Dummy'] = 0
full.loc[full['Complaint Has Video Evidence']==True, 'Video_Dummy'] = 1
full.loc[full['Is Full Investigation']==False, 'Partial_Investigation'] = 1
full.loc[full['Is Full Investigation']==True, 'Partial_Investigation'] = 0
full.loc[full['Is Full Investigation']==True, 'Full_Investigation'] = 1
full.loc[full['Is Full Investigation']==False, 'Full_Investigation'] = 0

# %%
a = full['Is Full Investigation'].value_counts().index.tolist()
b = full['Is Full Investigation'].value_counts().values.tolist()
f = {str(a): b for a,b in zip(a,b)}
p = pd.DataFrame.from_dict(f, orient='index', columns=['count'])
full
# Out:
#         DateStamp  UniqueComplaintId  Close Year  Received Year  \
# 0      2017-02-07                  6        2006           2006
# 1      2017-02-07                 11        2006           2006
# 2      2017-02-07                 20        2006           2005
# 7      2017-02-07                 26        2006           2006
# 11     2017-02-07                 38        2006           2005
# 14     2017-02-07                 43        2006           2006
# 18     2017-02-07                 68        2006           2006
# 20     2017-02-07                 81        2006           2006
# 21     2017-02-07                 84        2006           2005
# 27     2017-02-07                 89        2006           2006
# 30     2017-02-07                 93        2006           2006
# 31     2017-02-07                100        2006           2005
# 32     2017-02-07                102        2006           2005
# 43     2017-02-07                110        2006           2005
# 44     2017-02-07                112        2006           2006
# 46     2017-02-07                114        2006           2005
# 48     2017-02-07                120        2006           2006
# 49     2017-02-07                138        2006           2006
# 51     2017-02-07                142        2006           2005
# 55     2017-02-07                153        2006           2006
# 63     2017-02-07                162        2006           2006
# 66     2017-02-07                163        2006           2005
# 69     2017-02-07                172        2006           2006
# 71     2017-02-07                182        2006           2006
# 75     2017-02-07                194        2006           2005
# 76     2017-02-07                233        2006           2005
# 80     2017-02-07                237        2006           2006
# 83     2017-02-07                248        2006           2005
# 90     2017-02-07                249        2006           2006
# 92     2017-02-07                259        2006           2006
# ...           ...                ...         ...            ...
# 206614 2017-02-07              63750        2017           2016
# 206617 2017-02-07              64662        2017           2017
# 206618 2017-02-07              65184        2017           2016
# 206623 2017-02-07              65186        2017           2016
# 206624 2017-02-07              65440        2017           2017
# 206628 2017-02-07              65464        2017           2016
# 206635 2017-02-07              65476        2017           2016
# 206636 2017-02-07              65569        2017           2016
# 206638 2017-02-07              65739        2017           2016
# 206649 2017-02-07              66194        2017           2016
# 206652 2017-02-07              66351        2017           2016
# 206655 2017-02-07              66522        2017           2016
# 206657 2017-02-07              66650        2017           2016
# 206658 2017-02-07              67094        2017           2016
# 206663 2017-02-07              67104        2017           2016
# 206665 2017-02-07              67227        2017           2016
# 206667 2017-02-07              67415        2017           2016
# 206668 2017-02-07              68104        2017           2016
# 206672 2017-02-07              68560        2017           2016
# 206678 2017-02-07              68725        2017           2016
# 206679 2017-02-07              68986        2017           2016
# 206680 2017-02-07              69284        2017           2016
# 206688 2017-02-07              69482        2017           2016
# 206693 2017-02-07              69522        2017           2016
# 206694 2017-02-07              69674        2017           2016
# 206695 2017-02-07              69721        2017           2016
# 206703 2017-02-07              69975        2017           2016
# 206706 2017-02-07              70017        2017           2016
# 206707 2017-02-07              70045        2017           2017
# 206708 2017-02-07              70088        2017           2016
#
#        Borough of Occurrence  Is Full Investigation  \
# 0                   Brooklyn                  False
# 1                      Bronx                  False
# 2                      Bronx                  False
# 7                   Brooklyn                  False
# 11                     Bronx                   True
# 14                     Bronx                  False
# 18                  Brooklyn                  False
# 20                  Brooklyn                  False
# 21                 Manhattan                   True
# 27                  Brooklyn                  False
# 30                     Bronx                  False
# 31                 Manhattan                  False
# 32                    Queens                   True
# 43                  Brooklyn                   True
# 44                  Brooklyn                  False
# 46                 Manhattan                   True
# 48                     Bronx                  False
# 49                  Brooklyn                   True
# 51                  Brooklyn                  False
# 55                    Queens                   True
# 63                  Brooklyn                  False
# 66                 Manhattan                   True
# 69                     Bronx                  False
# 71                     Bronx                  False
# 75                 Manhattan                   True
# 76                  Brooklyn                   True
# 80                 Manhattan                  False
# 83                    Queens                   True
# 90                    Queens                  False
# 92                     Bronx                  False
# ...                      ...                    ...
# 206614                 Bronx                  False
# 206617                Queens                  False
# 206618         Staten Island                   True
# 206623             Manhattan                  False
# 206624             Manhattan                  False
# 206628                 Bronx                   True
# 206635             Manhattan                   True
# 206636         Staten Island                   True
# 206638                 Bronx                   True
# 206649                Queens                  False
# 206652             Manhattan                  False
# 206655             Manhattan                  False
# 206657                Queens                   True
# 206658                 Bronx                   True
# 206663              Brooklyn                  False
# 206665                Queens                  False
# 206667              Brooklyn                  False
# 206668                 Bronx                  False
# 206672                 Bronx                  False
# 206678             Manhattan                  False
# 206679                 Bronx                   True
# 206680              Brooklyn                   True
# 206688                Queens                   True
# 206693                Queens                  False
# 206694             Manhattan                  False
# 206695              Brooklyn                   True
# 206703             Manhattan                   True
# 206706                 Bronx                  False
# 206707                 Bronx                  False
# 206708              Brooklyn                   True
#
#         Complaint Has Video Evidence    Complaint Filed Mode  \
# 0                              False                   Phone
# 1                              False                   Phone
# 2                              False  Call Processing System
# 7                              False                   Phone
# 11                             False                   Phone
# 14                             False                   Phone
# 18                             False                   Phone
# 20                             False  Call Processing System
# 21                             False  Call Processing System
# 27                             False                   Phone
# 30                             False                   Phone
# 31                             False                   Phone
# 32                             False  Call Processing System
# 43                             False                   Phone
# 44                             False                   Phone
# 46                             False                   Phone
# 48                             False                   Phone
# 49                             False                   Phone
# 51                             False                   Phone
# 55                             False                   Phone
# 63                             False                   Phone
# 66                             False                   Phone
# 69                             False  Call Processing System
# 71                             False  Call Processing System
# 75                             False  Call Processing System
# 76                             False  Call Processing System
# 80                             False                   Phone
# 83                             False                   Phone
# 90                             False                   Phone
# 92                             False                   Phone
# ...                              ...                     ...
# 206614                         False                   Phone
# 206617                         False         On-line website
# 206618                         False                   Phone
# 206623                         False                   Phone
# 206624                         False                   Phone
# 206628                          True                   Phone
# 206635                         False         On-line website
# 206636                         False         On-line website
# 206638                          True  Call Processing System
# 206649                         False                   Phone
# 206652                         False                   Phone
# 206655                          True                   Phone
# 206657                         False         On-line website
# 206658                         False                   Phone
# 206663                         False                   Phone
# 206665                         False                   Phone
# 206667                         False                   Phone
# 206668                         False                   Phone
# 206672                         False                   Phone
# 206678                         False  Call Processing System
# 206679                         False         On-line website
# 206680                          True         On-line website
# 206688                         False               In-person
# 206693                          True                   Phone
# 206694                         False                   Phone
# 206695                         False                    Mail
# 206703                          True                   Phone
# 206706                         False                   Phone
# 206707                         False                   Phone
# 206708                         False                  E-mail
#
#        Complaint Filed Place  Complaint Contains Stop & Frisk Allegations  \
# 0                        IAB                                        False
# 1                        IAB                                        False
# 2                       CCRB                                         True
# 7                        IAB                                        False
# 11                      CCRB                                        False
# 14                      CCRB                                         True
# 18                       IAB                                        False
# 20                      CCRB                                         True
# 21                      CCRB                                         True
# 27                      CCRB                                        False
# 30                       IAB                                        False
# 31                      CCRB                                        False
# 32                      CCRB                                         True
# 43                      CCRB                                        False
# 44                      CCRB                                         True
# 46                      CCRB                                        False
# 48                       IAB                                        False
# 49                       IAB                                        False
# 51                      CCRB                                        False
# 55                      CCRB                                        False
# 63                       IAB                                        False
# 66                       IAB                                        False
# 69                      CCRB                                        False
# 71                      CCRB                                        False
# 75                      CCRB                                        False
# 76                      CCRB                                        False
# 80                       IAB                                        False
# 83                      CCRB                                        False
# 90                      CCRB                                        False
# 92                      CCRB                                         True
# ...                      ...                                          ...
# 206614                  CCRB                                         True
# 206617                  CCRB                                        False
# 206618                   IAB                                         True
# 206623                   IAB                                        False
# 206624                   IAB                                        False
# 206628                   IAB                                        False
# 206635                  CCRB                                        False
# 206636                  CCRB                                        False
# 206638                  CCRB                                         True
# 206649                   IAB                                        False
# 206652                   IAB                                        False
# 206655                   IAB                                        False
# 206657                  CCRB                                        False
# 206658                  CCRB                                         True
# 206663                   IAB                                        False
# 206665                  CCRB                                        False
# 206667                  CCRB                                        False
# 206668                   IAB                                        False
# 206672                  CCRB                                         True
# 206678                  CCRB                                        False
# 206679                  CCRB                                         True
# 206680                  CCRB                                         True
# 206688                  CCRB                                        False
# 206693                   IAB                                        False
# 206694                   IAB                                        False
# 206695                  CCRB                                         True
# 206703                   IAB                                        False
# 206706                  CCRB                                        False
# 206707                  CCRB                                        False
# 206708     Other City agency                                        False
#
#            Incident Location  Incident Year     Encounter Outcome  \
# 0             Street/highway           2006  No Arrest or Summons
# 55                                       Moving violation
# 63                                         Report-dispute
# 66                                  Demonstration/protest
# 69                                  Report of other crime
# 71                            Execution of search warrant
# 75                                   Parade/special event
# 76           PD suspected C/V of violation/crime - subway
# 80             PD suspected C/V of violation/crime - bldg
# 83                                                  Other
# 90                   C/V requested investigation of crime
# 92           PD suspected C/V of violation/crime - street
# ...                                                   ...
# 206614       PD suspected C/V of violation/crime - street
# 206617                                   Moving violation
# 206618                                   Moving violation
# 206623                              Report of other crime
# 206624                   C/V at PCT to obtain information
# 206628       PD suspected C/V of violation/crime - street
# 206635                                     EDP aided case
# 206636         PD suspected C/V of violation/crime - auto
# 206638       PD suspected C/V of violation/crime - street
# 206649       PD suspected C/V of violation/crime - street
# 206652       PD suspected C/V of violation/crime - street
# 206655       PD suspected C/V of violation/crime - street
# 206657                                              Other
# 206658       PD suspected C/V of violation/crime - street
# 206663       PD suspected C/V of violation/crime - subway
# 206665       PD suspected C/V of violation/crime - street
# 206667                              Report of other crime
# 206668                                 C/V telephoned PCT
# 206672       PD suspected C/V of violation/crime - street
# 206678       PD suspected C/V of violation/crime - street
# 206679       PD suspected C/V of violation/crime - street
# 206680       PD suspected C/V of violation/crime - street
# 206688               C/V requested investigation of crime
# 206693                    C/V requested info from officer
# 206694                                              Other
# 206695       PD suspected C/V of violation/crime - street
# 206703       PD suspected C/V of violation/crime - street
# 206706         PD suspected C/V of violation/crime - bldg
# 206707                                   Moving violation
# 206708       PD suspected C/V of violation/crime - street
#
#        Allegation FADO Type                 Allegation Description  \
# 0               Discourtesy                                 Action
# 1                     Force                         Physical force
# 2        Abuse of Authority                         Strip-searched
# 7        Abuse of Authority                       Threat of arrest
# 11       Abuse of Authority                       Property damaged
# 14       Abuse of Authority                         Strip-searched
# 18       Abuse of Authority       Premises entered and/or searched
# 20       Abuse of Authority                   Question and/or stop
# 21       Abuse of Authority                       Threat of arrest
# 27       Abuse of Authority                       Threat of arrest
# 30                    Force                         Physical force
# 31              Discourtesy                          Demeanor/tone
# 32       Abuse of Authority  Refusal to provide name/shield number
# 43              Discourtesy                                   Word
# 44       Abuse of Authority                   Question and/or stop
# 46       Abuse of Authority                       Property damaged
# 48       Abuse of Authority                       Threat of arrest
# 49       Abuse of Authority                       Threat of arrest
# 51              Discourtesy                                   Word
# 55       Abuse of Authority                       Property damaged
# 63              Discourtesy                                   Word
# 66       Abuse of Authority  Refusal to provide name/shield number
# 69       Abuse of Authority       Premises entered and/or searched
# 71       Abuse of Authority       Premises entered and/or searched
# 75                    Force                         Physical force
# 76              Discourtesy                                   Word
# 80       Abuse of Authority                       Threat of arrest
# 83       Abuse of Authority                       Threat of arrest
# 90       Abuse of Authority                       Threat of arrest
# 92       Abuse of Authority                   Question and/or stop
# ...                     ...                                    ...
# 206614   Abuse of Authority                           Vehicle stop
# 206617          Discourtesy                                   Word
# 206618   Abuse of Authority                           Vehicle stop
# 206623                Force                         Physical force
# 206624   Abuse of Authority   Threat of force (verbal or physical)
# 206628   Abuse of Authority                       Threat of arrest
# 206635   Abuse of Authority       Premises entered and/or searched
# 206636   Abuse of Authority                           Vehicle stop
# 206638   Abuse of Authority                       Threat of arrest
()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/anaconda3/envs/bikemap/lib/python3.7/site-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35     try:
# ---> 36         return f(*args, **kwargs)
#      37     except Exception as e:
#
# ~/anaconda3/envs/bikemap/lib/python3.7/site-packages/patsy/eval.py in eval(self, expr, source_name, inner_namespace)
#     165         return eval(code, {}, VarLookupDict([inner_namespace]
# --> 166                                             + self._namespaces))
#     167
#
# <string> in <module>()
#
# NameError: name 'Full_Investigation' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# <ipython-input-173-d5a3ab7c3eec> in <module>()
# ----> 1 evi = ols('Video_Dummy ~ Full_Investigation', data=df).fit()
#
# ~/anaconda3/envs/bikemap/lib/python3.7/site-packages/statsmodels/base/model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     153
#     154         tmp = handle_formula_data(data, None, formula, depth=eval_env,
# --> 155                                   missing=missing)
#     156         ((endog, exog), missing_idx, design_info) = tmp
#     157
#
# ~/anaconda3/envs/bikemap/lib/python3.7/site-packages/statsmodels/formula/formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      63         if data_util._is_using_pandas(Y, None):
#      64             result = dmatrices(formula, Y, depth, return_type='dataframe',
# ---> 65                                NA_action=na_action)
#      66         else:
#      67             result = dmatrices(formula, Y, depth, return_type='dataframe',
#
# ~/anaconda3/envs/bikemap/lib/python3.7/site-packages/patsy/highlevel.py in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
#     309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#     312         raise PatsyError("model is missing required outcome variables")
#
# ~/anaconda3/envs/bikemap/lib/python3.7/site-packages/patsy/highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     163         return iter([data])
#     164     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
# --> 165                                       NA_action)
#     166     if design_infos is not None:
#     167         return build_design_matrices(design_infos, data,
#
# ~/anaconda3/envs/bikemap/lib/python3.7/site-packages/patsy/highlevel.py in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      68                                       data_iter_maker,
#      69                                       eval_env,
# ---> 70                                       NA_action)
#      71     else:
#      72         return None
#
# ~/anaconda3/envs/bikemap/lib/python3.7/site-packages/patsy/build.py in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     694                                                    factor_states,
#     695                                                    data_iter_maker,
# --> 696                                                    NA_action)
#     697     # Now we need the factor infos, which encapsulate the knowledge of
#     698     # how to turn any given factor into a chunk of data:
#
# ~/anaconda3/envs/bikemap/lib/python3.7/site-packages/patsy/build.py in _examine_factor_types(factors, factor_states, data_iter_maker, NA_action)
#     441     for data in data_iter_maker():
#     442         for factor in list(examine_needed):
# --> 443             value = factor.eval(factor_states[factor], data)
#     444             if factor in cat_sniffers or guess_categorical(value):
#     445                 if factor not in cat_sniffers:
#
# ~/anaconda3/envs/bikemap/lib/python3.7/site-packages/patsy/eval.py in eval(self, memorize_state, data)
#     564         return self._eval(memorize_state["eval_code"],
#     565                           memorize_state,
# --> 566                           data)
#     567
#     568     __getstate__ = no_pickling
#
# ~/anaconda3/envs/bikemap/lib/python3.7/site-packages/patsy/eval.py in _eval(self, code, memorize_state, data)
#     549                                  memorize_state["eval_env"].eval,
#     550                                  code,
# --> 551                                  inner_namespace=inner_namespace)
#     552
#     553     def memorize_chunk(self, state, which_pass, data):
#
# ~/anaconda3/envs/bikemap/lib/python3.7/site-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      41                                  origin)
#      42             # Use 'exec' to hide this syntax from the Python 2 parser:
# ---> 43             exec("raise new_exc from e")
#      44         else:
#      45             # In python 2, we just let the original exception escape -- better
#
# ~/anaconda3/envs/bikemap/lib/python3.7/site-packages/patsy/compat.py in <module>()
#
# PatsyError: Error evaluating factor: NameError: name 'Full_Investigation' is not defined
#     Video_Dummy ~ Full_Investigation
#                   ^^^^^^^^^^^^^^^^^^

# %%
df.loc[df['type']=='Run', 'average_watts'] = 0
