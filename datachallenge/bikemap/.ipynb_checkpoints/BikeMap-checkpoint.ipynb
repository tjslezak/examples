# %%
from stravalib.client import Client
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sklearn
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
TOKEN='e090c0d0c061042b6af5569c5f00260fe212f63e'
client = Client(access_token=TOKEN)
client.get_athlete()
# Out:
# <Athlete id=4480876 firstname='Sarah' lastname='Cullen'>

# %%
activities = client.get_activities(limit=5000)

# %%
#smp = list(activities)[5]
#smp.to_dict()

# %%
my_cols =['distance', 
          'moving_time', 'elapsed_time',
          'elev_high', 'elev_low',
          'start_latlng', 'end_latlng',
          'total_elevation_gain',
          'type', 'start_date_local',
          'map']

# %%
data = []
for activity in activities:
    my_dict = activity.to_dict()
    data.append([my_dict.get(x) for x in my_cols])

# %%
import pandas as pd
df = pd.DataFrame(data, columns=my_cols)
df = df[df['type'].isin(['Ride','Run','Hike'])]
df.info
# Out:
# <bound method DataFrame.info of       distance moving_time elapsed_time  elev_high  elev_low   start_latlng  \
# 0       4081.5     0:59:35      1:02:46      639.0     416.1  33.58,-112.07
# 1      10573.4     1:30:43      1:33:14      560.6     426.0  33.53,-112.01
# 2       9983.1     1:06:11      1:06:36      457.0     387.3  33.56,-112.03
# 3       8238.3     1:20:27      1:24:36      592.9     424.2  33.53,-112.01
# 4       3221.5     0:18:36      0:18:45        4.9      -1.7     33.9,-78.4
# 5       6440.6     0:40:02      0:40:08        7.5      -3.4     33.9,-78.4
# 6      32194.6     1:33:46      1:34:19       16.5      -5.7     33.9,-78.4
# 7       4937.7     0:15:43      0:16:39        9.0      -3.4     33.9,-78.4
# 8      24149.3     1:07:17      1:07:17       13.6      -5.7     33.9,-78.4
# 10      4993.3     0:28:42      0:28:42        7.5      -3.4     33.9,-78.4
# 12      1688.4     0:09:39      0:09:44        4.9       0.5     33.9,-78.4
# 13     11521.2     1:59:27      2:04:58      679.3     373.0  33.37,-111.99
# 14      6443.1     1:04:18      1:04:31      878.7     692.9  33.73,-111.86
# 15      8361.4     1:07:35      1:09:32      625.0     490.1   33.74,-112.1
# 16     32298.0     1:18:50      1:19:30      431.5     351.4  33.51,-112.05
# 17      9509.5     2:26:52      2:32:32      817.2     414.2  33.51,-111.94
# 18      6672.3     0:57:41      0:59:15      508.7     404.0  33.69,-112.19
# 19      8048.2     1:13:14      1:15:31      543.9     376.0  33.37,-111.99
# 20      5026.9     1:25:26      1:44:31      815.9     434.0  33.52,-111.97
# 21      6571.4     1:00:45      1:01:09      503.0     423.7  33.56,-112.03
# 22      8054.7     1:09:21      1:10:39      560.6     426.0  33.53,-112.01
# 23     15107.7     1:12:23      1:18:51     2088.0    2031.8   35.2,-111.56
# 24      3058.4     0:23:18      0:25:12     2088.0    2066.2   35.2,-111.56
# 25      5147.7     0:54:52      0:58:51     1953.8    1848.0  35.78,-106.27
# 26     17829.5     0:47:13      0:52:43     2251.9    2169.0  35.89,-106.29
# 27      1803.8     0:16:40      0:23:32      345.7     315.4   36.59,-93.83
# 28      5027.6     0:48:13      0:51:49      440.4     313.0   36.58,-93.81
# 29      4995.3     0:28:19      0:28:19      243.0     228.9   42.41,-83.46
# 30     67832.4     2:40:18      2:47:59      241.8     189.6   42.41,-83.46
# 31     51350.8     1:54:57      2:01:56      245.2     179.4   42.41,-83.46
# 1320   42.41,-83.46                  50.7  Ride  2014-04-18T16:57:52
# 1321   42.45,-83.43                 135.8  Ride  2014-04-18T14:18:32
# 1322   42.41,-83.46                 102.9  Ride  2014-04-17T18:51:18
# 1323    41.7,-86.23                 103.0  Ride  2014-04-16T13:17:05
# 1325           None                   0.0   Run  2014-04-15T00:00:00
#
#                                                     map
# 0     {'id': 'a1715267499', 'polyline': None, 'summa...
# 1     {'id': 'a1713128476', 'polyline': None, 'summa...
# 2     {'id': 'a1708472102', 'polyline': None, 'summa...
# 3     {'id': 'a1704542467', 'polyline': None, 'summa...
# 4     {'id': 'a1701610090', 'polyline': None, 'summa...
# 5     {'id': 'a1699754642', 'polyline': None, 'summa...
# 6     {'id': 'a1697681372', 'polyline': None, 'summa...
# 7     {'id': 'a1696298966', 'polyline': None, 'summa...
# 8     {'id': 'a1695607649', 'polyline': None, 'summa...
# 10    {'id': 'a1691154782', 'polyline': None, 'summa...
# 12    {'id': 'a1688809049', 'polyline': None, 'summa...
# 13    {'id': 'a1680446036', 'polyline': None, 'summa...
# 14    {'id': 'a1678120879', 'polyline': None, 'summa...
# 15    {'id': 'a1676146953', 'polyline': None, 'summa...
# 16    {'id': 'a1674170433', 'polyline': None, 'summa...
# 17    {'id': 'a1671938351', 'polyline': None, 'summa...
# 18    {'id': 'a1667762823', 'polyline': None, 'summa...
# 19    {'id': 'a1665721122', 'polyline': None, 'summa...
# 20    {'id': 'a1661370444', 'polyline': None, 'summa...
# 21    {'id': 'a1659746273', 'polyline': None, 'summa...
# 22    {'id': 'a1656852679', 'polyline': None, 'summa...
# 23    {'id': 'a1653399174', 'polyline': None, 'summa...
# 24    {'id': 'a1653186300', 'polyline': None, 'summa...
# 25    {'id': 'a1651890090', 'polyline': None, 'summa...
# 26    {'id': 'a1651407990', 'polyline': None, 'summa...
# 27    {'id': 'a1649597026', 'polyline': None, 'summa...
# 28    {'id': 'a1649597037', 'polyline': None, 'summa...
# 29    {'id': 'a1636077643', 'polyline': None, 'summa...
# 30    {'id': 'a1634065237', 'polyline': None, 'summa...
# 31    {'id': 'a1632043667', 'polyline': None, 'summa...
# ...                                                 ...
# 1294  {'id': 'a140024444', 'polyline': None, 'summar...
# 1295  {'id': 'a139680264', 'polyline': None, 'summar...
# 1296  {'id': 'a139676599', 'polyline': None, 'summar...
# 1297  {'id': 'a139586190', 'polyline': None, 'summar...
# 1298  {'id': 'a138921874', 'polyline': None, 'summar...
# 1299  {'id': 'a138489470', 'polyline': None, 'summar...
# 1300  {'id': 'a137933366', 'polyline': None, 'summar...
# 1301  {'id': 'a137834010', 'polyline': None, 'summar...
# 1302  {'id': 'a137346651', 'polyline': None, 'summar...
# 1303  {'id': 'a137088263', 'polyline': None, 'summar...
# 1304  {'id': 'a137020799', 'polyline': None, 'summar...
# 1305  {'id': 'a136945779', 'polyline': None, 'summar...
# 1306  {'id': 'a136644721', 'polyline': None, 'summar...
# 1307  {'id': 'a136626910', 'polyline': None, 'summar...
# 1308  {'id': 'a136536688', 'polyline': None, 'summar...
# 1309  {'id': 'a136170037', 'polyline': None, 'summar...
# 1310  {'id': 'a135951285', 'polyline': None, 'summar...
# 1311  {'id': 'a135556018', 'polyline': None, 'summar...
# 1312  {'id': 'a135684087', 'polyline': None, 'summar...
# 1313  {'id': 'a134110051', 'polyline': None, 'summar...
# 1314  {'id': 'a133507283', 'polyline': None, 'summar...
# 1315  {'id': 'a133468246', 'polyline': None, 'summar...
# 1317  {'id': 'a133145352', 'polyline': None, 'summar...
# 1318  {'id': 'a132789419', 'polyline': None, 'summar...
# 1319  {'id': 'a132325993', 'polyline': None, 'summar...
# 1320  {'id': 'a131642098', 'polyline': None, 'summar...
# 1321  {'id': 'a131629296', 'polyline': None, 'summar...
# 1322  {'id': 'a131321418', 'polyline': None, 'summar...
# 1323  {'id': 'a130942883', 'polyline': None, 'summar...
# 1325  {'id': 'a130714634', 'polyline': None, 'summar...
#
# [1257 rows x 11 columns]>

# %%
df.loc[df['type']=='Run', 'average_watts'] = 0
df.info
# Out:
# <bound method DataFrame.info of       distance moving_time elapsed_time  elev_high  elev_low   start_latlng  \
# 0       4081.5     0:59:35      1:02:46      639.0     416.1  33.58,-112.07
# 1      10573.4     1:30:43      1:33:14      560.6     426.0  33.53,-112.01
# 2       9983.1     1:06:11      1:06:36      457.0     387.3  33.56,-112.03
# 3       8238.3     1:20:27      1:24:36      592.9     424.2  33.53,-112.01
# 4       3221.5     0:18:36      0:18:45        4.9      -1.7     33.9,-78.4
# 5       6440.6     0:40:02      0:40:08        7.5      -3.4     33.9,-78.4
# 6      32194.6     1:33:46      1:34:19       16.5      -5.7     33.9,-78.4
# 7       4937.7     0:15:43      0:16:39        9.0      -3.4     33.9,-78.4
# 8      24149.3     1:07:17      1:07:17       13.6      -5.7     33.9,-78.4
# 10      4993.3     0:28:42      0:28:42        7.5      -3.4     33.9,-78.4
# 12      1688.4     0:09:39      0:09:44        4.9       0.5     33.9,-78.4
# 13     11521.2     1:59:27      2:04:58      679.3     373.0  33.37,-111.99
# 14      6443.1     1:04:18      1:04:31      878.7     692.9  33.73,-111.86
# 15      8361.4     1:07:35      1:09:32      625.0     490.1   33.74,-112.1
# 16     32298.0     1:18:50      1:19:30      431.5     351.4  33.51,-112.05
# 17      9509.5     2:26:52      2:32:32      817.2     414.2  33.51,-111.94
# 18      6672.3     0:57:41      0:59:15      508.7     404.0  33.69,-112.19
# 19      8048.2     1:13:14      1:15:31      543.9     376.0  33.37,-111.99
# 20      5026.9     1:25:26      1:44:31      815.9     434.0  33.52,-111.97
# 21      6571.4     1:00:45      1:01:09      503.0     423.7  33.56,-112.03
# 22      8054.7     1:09:21      1:10:39      560.6     426.0  33.53,-112.01
# 23     15107.7     1:12:23      1:18:51     2088.0    2031.8   35.2,-111.56
# 24      3058.4     0:23:18      0:25:12     2088.0    2066.2   35.2,-111.56
# 25      5147.7     0:54:52      0:58:51     1953.8    1848.0  35.78,-106.27
# 26     17829.5     0:47:13      0:52:43     2251.9    2169.0  35.89,-106.29
# 27      1803.8     0:16:40      0:23:32      345.7     315.4   36.59,-93.83
# 28      5027.6     0:48:13      0:51:49      440.4     313.0   36.58,-93.81
# 1317    41.7,-86.23                 177.5  Ride  2014-04-22T17:35:25
# 1318    41.7,-86.23                   0.0   Run  2014-04-21T17:09:15
# 1319   42.41,-83.46                 195.2  Ride  2014-04-20T11:01:40
# 1320   42.41,-83.46                  50.7  Ride  2014-04-18T16:57:52
# 1321   42.45,-83.43                 135.8  Ride  2014-04-18T14:18:32
# 1322   42.41,-83.46                 102.9  Ride  2014-04-17T18:51:18
# 1323    41.7,-86.23                 103.0  Ride  2014-04-16T13:17:05
# 1325           None                   0.0   Run  2014-04-15T00:00:00
#
#                                                     map  average_watts
# 0     {'id': 'a1715267499', 'polyline': None, 'summa...            NaN
# 1     {'id': 'a1713128476', 'polyline': None, 'summa...            0.0
# 2     {'id': 'a1708472102', 'polyline': None, 'summa...            0.0
# 3     {'id': 'a1704542467', 'polyline': None, 'summa...            0.0
# 4     {'id': 'a1701610090', 'polyline': None, 'summa...            0.0
# 5     {'id': 'a1699754642', 'polyline': None, 'summa...            0.0
# 6     {'id': 'a1697681372', 'polyline': None, 'summa...            NaN
# 7     {'id': 'a1696298966', 'polyline': None, 'summa...            NaN
# 8     {'id': 'a1695607649', 'polyline': None, 'summa...            NaN
# 10    {'id': 'a1691154782', 'polyline': None, 'summa...            0.0
# 12    {'id': 'a1688809049', 'polyline': None, 'summa...            0.0
# 13    {'id': 'a1680446036', 'polyline': None, 'summa...            NaN
# 14    {'id': 'a1678120879', 'polyline': None, 'summa...            0.0
# 15    {'id': 'a1676146953', 'polyline': None, 'summa...            0.0
# 16    {'id': 'a1674170433', 'polyline': None, 'summa...            NaN
# 17    {'id': 'a1671938351', 'polyline': None, 'summa...            0.0
# 18    {'id': 'a1667762823', 'polyline': None, 'summa...            0.0
# 19    {'id': 'a1665721122', 'polyline': None, 'summa...            0.0
# 20    {'id': 'a1661370444', 'polyline': None, 'summa...            NaN
# 21    {'id': 'a1659746273', 'polyline': None, 'summa...            0.0
# 22    {'id': 'a1656852679', 'polyline': None, 'summa...            0.0
# 23    {'id': 'a1653399174', 'polyline': None, 'summa...            NaN
# 24    {'id': 'a1653186300', 'polyline': None, 'summa...            0.0
# 25    {'id': 'a1651890090', 'polyline': None, 'summa...            0.0
# 26    {'id': 'a1651407990', 'polyline': None, 'summa...            NaN
# 27    {'id': 'a1649597026', 'polyline': None, 'summa...            0.0
# 28    {'id': 'a1649597037', 'polyline': None, 'summa...            NaN
# 29    {'id': 'a1636077643', 'polyline': None, 'summa...            0.0
# 30    {'id': 'a1634065237', 'polyline': None, 'summa...            NaN
# 31    {'id': 'a1632043667', 'polyline': None, 'summa...            NaN
# ...                                                 ...            ...
# 1294  {'id': 'a140024444', 'polyline': None, 'summar...            NaN
# 1295  {'id': 'a139680264', 'polyline': None, 'summar...            0.0
# 1296  {'id': 'a139676599', 'polyline': None, 'summar...            NaN
# 1297  {'id': 'a139586190', 'polyline': None, 'summar...            NaN
# 1298  {'id': 'a138921874', 'polyline': None, 'summar...            NaN
# 1299  {'id': 'a138489470', 'polyline': None, 'summar...            0.0
# 1300  {'id': 'a137933366', 'polyline': None, 'summar...            NaN
# 1301  {'id': 'a137834010', 'polyline': None, 'summar...            NaN
# 1302  {'id': 'a137346651', 'polyline': None, 'summar...            NaN
# 1303  {'id': 'a137088263', 'polyline': None, 'summar...            NaN
# 1304  {'id': 'a137020799', 'polyline': None, 'summar...            0.0
# 1305  {'id': 'a136945779', 'polyline': None, 'summar...            NaN
# 1306  {'id': 'a136644721', 'polyline': None, 'summar...            NaN
# 1307  {'id': 'a136626910', 'polyline': None, 'summar...            NaN
# 1308  {'id': 'a136536688', 'polyline': None, 'summar...            0.0
# 1309  {'id': 'a136170037', 'polyline': None, 'summar...            0.0
# 1310  {'id': 'a135951285', 'polyline': None, 'summar...            NaN
# 1311  {'id': 'a135556018', 'polyline': None, 'summar...            NaN
# 1312  {'id': 'a135684087', 'polyline': None, 'summar...            0.0
# 1313  {'id': 'a134110051', 'polyline': None, 'summar...            NaN
# 1314  {'id': 'a133507283', 'polyline': None, 'summar...            NaN
# 1315  {'id': 'a133468246', 'polyline': None, 'summar...            NaN
# 1317  {'id': 'a133145352', 'polyline': None, 'summar...            NaN
# 1318  {'id': 'a132789419', 'polyline': None, 'summar...            0.0
# 1319  {'id': 'a132325993', 'polyline': None, 'summar...            NaN
# 1320  {'id': 'a131642098', 'polyline': None, 'summar...            NaN
# 1321  {'id': 'a131629296', 'polyline': None, 'summar...            NaN
# 1322  {'id': 'a131321418', 'polyline': None, 'summar...            NaN
# 1323  {'id': 'a130942883', 'polyline': None, 'summar...            NaN
# 1325  {'id': 'a130714634', 'polyline': None, 'summar...            0.0
#
# [1257 rows x 12 columns]>

# %%
df.drop('average_watts', axis=1, inplace=True)
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1189 entries, 0 to 1323
# Data columns (total 11 columns):
# distance                1189 non-null float64
# moving_time             1189 non-null object
# elapsed_time            1189 non-null object
# elev_high               1189 non-null float64
# elev_low                1189 non-null float64
# start_latlng            1189 non-null object
# end_latlng              1189 non-null object
# total_elevation_gain    1189 non-null float64
# type                    1189 non-null object
# start_date_local        1189 non-null object
# map                     1189 non-null object
# dtypes: float64(4), object(7)
# memory usage: 111.5+ KB

# %%
df['distance'] = df['distance']/1000
df['distance'] = df['distance'].round(2)

# %%
df['elapsed_time'].str.len().value_counts()
# Out:
# 7    1189
# Name: elapsed_time, dtype: int64

# %%
def get_minutes(time_str):
    
    h, m, s = time_str.split(':') 
    total_min = int(h)*60+int(m)+int(s)/60
    return int(total_min)

# %%
df['time_min'] = df['elapsed_time'].apply(get_minutes)

# %%
df.drop('elapsed_time', axis=1, inplace=True)
df.head()
# Out:
#    distance moving_time  elev_high  elev_low   start_latlng     end_latlng  \
# 0      4.08     0:59:35      639.0     416.1  33.58,-112.07  33.58,-112.07
# 1     10.57     1:30:43      560.6     426.0  33.53,-112.01  33.53,-112.01
# 2      9.98     1:06:11      457.0     387.3  33.56,-112.03  33.56,-112.03
# 3      8.24     1:20:27      592.9     424.2  33.53,-112.01  33.53,-112.01
# 4      3.22     0:18:36        4.9      -1.7     33.9,-78.4     33.9,-78.4
#
#    total_elevation_gain  type     start_date_local  \
# 0                 267.0  Hike  2018-07-20T05:50:34
# 1                 343.7   Run  2018-07-19T05:28:58
# 2                 126.6   Run  2018-07-17T05:39:15
# 3                 357.9   Run  2018-07-15T05:51:34
# 4                  10.7   Run  2018-07-14T07:30:00
#
#                                                  map  time_min
# 0  {'id': 'a1715267499', 'polyline': None, 'summa...        62
# 1  {'id': 'a1713128476', 'polyline': None, 'summa...        93
# 2  {'id': 'a1708472102', 'polyline': None, 'summa...        66
# 3  {'id': 'a1704542467', 'polyline': None, 'summa...        84
# 4  {'id': 'a1701610090', 'polyline': None, 'summa...        18

# %%
df['start_date_local'] = pd.to_datetime(df['start_date_local'])
df.set_index('start_date_local', inplace=True)
df.head()
# Out:
#                      distance moving_time  elev_high  elev_low   start_latlng  \
# start_date_local
# 2018-07-20 05:50:34      4.08     0:59:35      639.0     416.1  33.58,-112.07
# 2018-07-19 05:28:58     10.57     1:30:43      560.6     426.0  33.53,-112.01
# 2018-07-17 05:39:15      9.98     1:06:11      457.0     387.3  33.56,-112.03
# 2018-07-15 05:51:34      8.24     1:20:27      592.9     424.2  33.53,-112.01
# 2018-07-14 07:30:00      3.22     0:18:36        4.9      -1.7     33.9,-78.4
#
#                         end_latlng  total_elevation_gain  type  \
# start_date_local
# 2018-07-20 05:50:34  33.58,-112.07                 267.0  Hike
# 2018-07-19 05:28:58  33.53,-112.01                 343.7   Run
# 2018-07-17 05:39:15  33.56,-112.03                 126.6   Run
# 2018-07-15 05:51:34  33.53,-112.01                 357.9   Run
# 2018-07-14 07:30:00     33.9,-78.4                  10.7   Run
#
#                                                                    map  \
# start_date_local
# 2018-07-20 05:50:34  {'id': 'a1715267499', 'polyline': None, 'summa...
# 2018-07-19 05:28:58  {'id': 'a1713128476', 'polyline': None, 'summa...
# 2018-07-17 05:39:15  {'id': 'a1708472102', 'polyline': None, 'summa...
# 2018-07-15 05:51:34  {'id': 'a1704542467', 'polyline': None, 'summa...
# 2018-07-14 07:30:00  {'id': 'a1701610090', 'polyline': None, 'summa...
#
#                      time_min
# start_date_local
# 2018-07-20 05:50:34        62
# 2018-07-19 05:28:58        93
# 2018-07-17 05:39:15        66
# 2018-07-15 05:51:34        84
# 2018-07-14 07:30:00        18

# %%
df.index = df.index.round('D', inplace=True)
df.index.rename('date', inplace=True)
df.head()
# Out:
#             distance moving_time  elev_high  elev_low   start_latlng  \
# date
# 2018-07-20      4.08     0:59:35      639.0     416.1  33.58,-112.07
# 2018-07-19     10.57     1:30:43      560.6     426.0  33.53,-112.01
# 2018-07-17      9.98     1:06:11      457.0     387.3  33.56,-112.03
# 2018-07-15      8.24     1:20:27      592.9     424.2  33.53,-112.01
# 2018-07-14      3.22     0:18:36        4.9      -1.7     33.9,-78.4
#
#                end_latlng  total_elevation_gain  type  \
# date
# 2018-07-20  33.58,-112.07                 267.0  Hike
# 2018-07-19  33.53,-112.01                 343.7   Run
# 2018-07-17  33.56,-112.03                 126.6   Run
# 2018-07-15  33.53,-112.01                 357.9   Run
# 2018-07-14     33.9,-78.4                  10.7   Run
#
#                                                           map  time_min
# date
# 2018-07-20  {'id': 'a1715267499', 'polyline': None, 'summa...        62
# 2018-07-19  {'id': 'a1713128476', 'polyline': None, 'summa...        93
# 2018-07-17  {'id': 'a1708472102', 'polyline': None, 'summa...        66
# 2018-07-15  {'id': 'a1704542467', 'polyline': None, 'summa...        84
# 2018-07-14  {'id': 'a1701610090', 'polyline': None, 'summa...        18

# %%
grouped = df.groupby('type')
def f(group):
    return (group-group.mean()).abs().div(group.std())

# %%
grouped.transform(f).head()
outliers = grouped.transform(f) > 3
df = df[~outliers.any(axis=1)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1128 entries, 2018-07-20 to 2014-04-17
# Data columns (total 10 columns):
# distance                1128 non-null float64
# moving_time             1128 non-null object
# elev_high               1128 non-null float64
# elev_low                1128 non-null float64
# start_latlng            1128 non-null object
# end_latlng              1128 non-null object
# total_elevation_gain    1128 non-null float64
# type                    1128 non-null object
# map                     1128 non-null object
# time_min                1128 non-null int64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 96.9+ KB

# %%
df.drop('map', axis=1, inplace=True)
df.head()
# Out:
# /Users/tjs/anaconda3/envs/bikemap/lib/python3.7/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#             distance moving_time  elev_high  elev_low   start_latlng  \
# date
# 2018-07-20      4.08     0:59:35      639.0     416.1  33.58,-112.07
# 2018-07-19     10.57     1:30:43      560.6     426.0  33.53,-112.01
# 2018-07-17      9.98     1:06:11      457.0     387.3  33.56,-112.03
# 2018-07-15      8.24     1:20:27      592.9     424.2  33.53,-112.01
# 2018-07-14      3.22     0:18:36        4.9      -1.7     33.9,-78.4
#
#                end_latlng  total_elevation_gain  type  time_min
# date
# 2018-07-20  33.58,-112.07                 267.0  Hike        62
# 2018-07-19  33.53,-112.01                 343.7   Run        93
# 2018-07-17  33.56,-112.03                 126.6   Run        66
# 2018-07-15  33.53,-112.01                 357.9   Run        84
# 2018-07-14     33.9,-78.4                  10.7   Run        18

# %%
df.head()
# Out:
#             distance moving_time  elev_high  elev_low   start_latlng  \
# date
# 2018-07-20      4.08     0:59:35      639.0     416.1  33.58,-112.07
# 2018-07-19     10.57     1:30:43      560.6     426.0  33.53,-112.01
# 2018-07-17      9.98     1:06:11      457.0     387.3  33.56,-112.03
# 2018-07-15      8.24     1:20:27      592.9     424.2  33.53,-112.01
# 2018-07-14      3.22     0:18:36        4.9      -1.7     33.9,-78.4
#
#                end_latlng  total_elevation_gain  type  time_min
# date
# 2018-07-20  33.58,-112.07                 267.0  Hike        62
# 2018-07-19  33.53,-112.01                 343.7   Run        93
# 2018-07-17  33.56,-112.03                 126.6   Run        66
# 2018-07-15  33.53,-112.01                 357.9   Run        84
# 2018-07-14     33.9,-78.4                  10.7   Run        18

# %%
sns.countplot(df['type'])
plt.title('Types of activities')
# Out:
# Text(0.5,1,'Types of activities')

# %%
sns.pairplot(df, hue='type')

# %%
corr = df.corr()
plt.figure(figsize = (12,8))
sns.heatmap(corr, annot=True, fmt=".2f");

# %%
trends = df.copy()
trends.set_index(pd.to_datetime(trends.index), drop=True, inplace=True)
trends['weekday'] = trends.index.map(lambda x: x.weekday)
trends.groupby('weekday').mean()
trends.groupby('weekday').mean()['time_min'].plot(kind='bar')

# %%
import calendar
list(calendar.day_name)
trends.groupby('weekday').mean()['time_min'].plot(kind='bar', figsize=(12,5));
plt.xticks(list(range(7)), list(calendar.day_name), rotation='horizontal');
plt.xlabel('')
plt.ylabel('Time in minutes')
plt.title('Average training time by day of the week')
# Out:
# Text(0.5,1,'Average training time by day of the week')

# %%
trends['year'] = trends.index.map(lambda x: x.year)
grouped = trends.groupby(['year', 'type']).mean()
grouped['time_min'].plot(kind='bar')

# %%
grouped['time_min'].unstack('type')
result = grouped['time_min'].unstack('type').fillna(0)
result.plot(kind='bar', stacked=True)
plt.title('Yearly average for cycling and running')
# Out:
# Text(0.5,1,'Yearly average for cycling and running')

# %%
df = df[df['type']=="Ride"]
df.drop(['type'], axis=1, inplace=True)
# Out:
# /Users/tjs/anaconda3/envs/bikemap/lib/python3.7/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
cols = ['distance', 'total_elevation_gain', 'time_min']
sns.pairplot(x_vars=cols, y_vars=cols, data=df, height=5)

# %%
df.head()
# Out:
#             distance moving_time  elev_high  elev_low   start_latlng  \
# date
# 2018-07-12     32.19     1:33:46       16.5      -5.7     33.9,-78.4
# 2018-07-12      4.94     0:15:43        9.0      -3.4     33.9,-78.4
# 2018-07-11     24.15     1:07:17       13.6      -5.7     33.9,-78.4
# 2018-07-01     32.30     1:18:50      431.5     351.4  33.51,-112.05
# 2018-06-12     67.83     2:40:18      241.8     189.6   42.41,-83.46
#
#                end_latlng  total_elevation_gain  time_min
# date
# 2018-07-12     33.9,-78.4                 150.0        94
# 2018-07-12   33.89,-78.45                  43.0        16
# 2018-07-11     33.9,-78.4                 145.8        67
# 2018-07-01  33.51,-112.05                 201.1        79
# 2018-06-12   42.41,-83.46                 196.0       167

# %%
df.drop(['start_latlng'], axis=1, inplace=True)
df.drop(['end_latlng'], axis=1, inplace=True)
# Out:
# /Users/tjs/anaconda3/envs/bikemap/lib/python3.7/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
df.drop(['moving_time'], axis=1, inplace=True)
df.head()
# Out:
# /Users/tjs/anaconda3/envs/bikemap/lib/python3.7/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#             distance  elev_high  elev_low  total_elevation_gain  time_min
# date
# 2018-07-12     32.19       16.5      -5.7                 150.0        94
# 2018-07-12      4.94        9.0      -3.4                  43.0        16
# 2018-07-11     24.15       13.6      -5.7                 145.8        67
# 2018-07-01     32.30      431.5     351.4                 201.1        79
# 2018-06-12     67.83      241.8     189.6                 196.0       167

# %%
X = StandardScaler().fit_transform(df)

# %%
from sklearn.cluster import KMeans
model = KMeans(n_clusters=4)
model.fit(X)
df['Cluster'] = model.labels_
# Out:
# /Users/tjs/anaconda3/envs/bikemap/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
cols = ['distance', 'total_elevation_gain', 'time_min']

sns.pairplot(x_vars=cols, y_vars=cols, hue='Cluster', data=df)

# %%
df.groupby('Cluster').mean()
# Out:
#           distance   elev_high    elev_low  total_elevation_gain    time_min
# Cluster
# 0        41.274818  282.844545  225.797879            150.477273  102.196970
# 1        23.657857  700.553571  540.842857            306.850000   71.142857
# 2        68.262372  280.385256  204.121795            299.375000  166.916667
# 3        15.612968  222.758304  193.040989             52.575618   52.720848

# %%
df.groupby('Cluster').std()
# Out:
#           distance   elev_high    elev_low  total_elevation_gain   time_min
# Cluster
# 0         9.605579   64.895250   58.364650             85.151858  23.642101
# 1        18.936694  157.145796  157.253908            233.404358  49.604147
# 2        14.509401   74.338332   44.555669            146.336496  32.710649
# 3        10.641563   69.224701   67.143757             54.424662  27.369481
